# %%
import warnings
warnings.filterwarnings("ignore")

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
# Load the dataset

# Define the data types for columns 0 and 24 as strings
dtype_dict = {'Rowid': str, 'Geolocation': str}

# Load the dataset with specified data types
data = pd.read_csv("Disability_and_Health_Data_System__DHDS_.csv", dtype=dtype_dict)
df = data.copy()

# %%
# Display the data types of each column
print(df.dtypes)
# Out:
# Rowid                          object
# Year                            int64
# LocationAbbr                   object
# LocationDesc                   object
# DataSource                     object
# Category                       object
# Indicator                      object
# Response                       object
# Data_Value_Unit                object
# Data_Value_Type                object
# Data_Value                    float64
# Data_Value_Alt                float64
# Data_Value_Footnote_Symbol     object
# Data_Value_Footnote            object
# Low_Confidence_Limit          float64
# High_Confidence_Limit         float64
# Number                        float64
# WeightedNumber                float64
# StratificationCategory1        object
# Stratification1                object
# StratificationCategory2        object
# Stratification2                object
# CategoryID                     object
# IndicatorID                    object
# Geolocation                    object
# LocationID                      int64
# ResponseID                     object
# DataValueTypeID                object
# StratificationCategoryID1      object
# StratificationID1              object
# StratificationCategoryID2      object
# StratificationID2              object
# dtype: object

# %%
#Getting data types of the columns and non-null counts
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 644356 entries, 0 to 644355
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Rowid                       525827 non-null  object
#  1   Year                        644356 non-null  int64
#  2   LocationAbbr                644356 non-null  object
#  3   LocationDesc                644356 non-null  object
#  4   DataSource                  644356 non-null  object
#  5   Category                    644356 non-null  object
#  6   Indicator                   644356 non-null  object
#  7   Response                    635140 non-null  object
#  8   Data_Value_Unit             644356 non-null  object
#  9   Data_Value_Type             644356 non-null  object
#  10  Data_Value                  578578 non-null  float64
#  11  Data_Value_Alt              578578 non-null  float64
#  12  Data_Value_Footnote_Symbol  65778 non-null   object
#  13  Data_Value_Footnote         65778 non-null   object
#  14  Low_Confidence_Limit        578578 non-null  float64
#  15  High_Confidence_Limit       578578 non-null  float64
#  16  Number                      578578 non-null  float64
#  17  WeightedNumber              578578 non-null  float64
#  18  StratificationCategory1     644356 non-null  object
#  19  Stratification1             644356 non-null  object
#  20  StratificationCategory2     409720 non-null  object
#  21  Stratification2             409720 non-null  object
#  22  CategoryID                  644356 non-null  object
#  23  IndicatorID                 644356 non-null  object
#  24  Geolocation                 77200 non-null   object
#  25  LocationID                  644356 non-null  int64
#  26  ResponseID                  644356 non-null  object
#  27  DataValueTypeID             644356 non-null  object
#  28  StratificationCategoryID1   644356 non-null  object
#  29  StratificationID1           644356 non-null  object
#  30  StratificationCategoryID2   409720 non-null  object
#  31  StratificationID2           409720 non-null  object
# dtypes: float64(6), int64(2), object(24)
# memory usage: 157.3+ MB

# %%
#Getting number of columns per data type
df.dtypes.value_counts()
# Out:
# object     24
# float64     6
# int64       2
# Name: count, dtype: int64

# %%
# Identify column names containing categorical data
categorical_col = df.select_dtypes(object).columns
print(categorical_col)
# Out:
# Index(['Rowid', 'LocationAbbr', 'LocationDesc', 'DataSource', 'Category',
#        'Indicator', 'Response', 'Data_Value_Unit', 'Data_Value_Type',
#        'Data_Value_Footnote_Symbol', 'Data_Value_Footnote',
#        'StratificationCategory1', 'Stratification1', 'StratificationCategory2',
#        'Stratification2', 'CategoryID', 'IndicatorID', 'Geolocation',
#        'ResponseID', 'DataValueTypeID', 'StratificationCategoryID1',
#        'StratificationID1', 'StratificationCategoryID2', 'StratificationID2'],
#       dtype='object')

# %%
# Isolate all columns containing categorical data
data_categorical = df[categorical_col]
data_categorical.head()
# Out:
#                                  Rowid LocationAbbr          LocationDesc  \
# 0  2019~11~JOB01~JOB~DISTYPE~SELFDIS~~           DC  District of Columbia
# 1                                  NaN           NJ            New Jersey
# 2                                  NaN           WV         West Virginia
# 3                                  NaN           RI          Rhode Island
# 4                                  NaN         HHS8          HHS Region 8
#
#   DataSource      Category                                          Indicator  \
# 0      BRFSS  Demographics  Employment status among adults 18 years of age...
# 1      BRFSS  Demographics  Education level among adults 18 years of age o...
# 2      BRFSS  Demographics  Education level among adults 18 years of age o...
# 3      BRFSS  Demographics  Income level among adults 18 years of age or o...
# 4      BRFSS  Demographics  Income level among adults 18 years of age or o...
#
#                Response Data_Value_Unit          Data_Value_Type  \
# 0              Employed               %  Age-adjusted Prevalence
# 1      College Graduate               %  Age-adjusted Prevalence
# 2  High School Graduate               %  Age-adjusted Prevalence
# 3   $25,000 to <$35,000               %  Age-adjusted Prevalence
# 4   $25,000 to <$35,000               %  Age-adjusted Prevalence
#
#   Data_Value_Footnote_Symbol  ... Stratification2 CategoryID IndicatorID  \
# 0                          *  ...             NaN      DEMOG         JOB
# 1                        NaN  ...             NaN      DEMOG     EDUCATE
# 2                        NaN  ...             NaN      DEMOG     EDUCATE
# 3                        NaN  ...             NaN      DEMOG     INCOMEN
# 4                        NaN  ...             NaN      DEMOG     INCOMEN
#
#   Geolocation ResponseID DataValueTypeID StratificationCategoryID1  \
# 0         NaN      JOB01      AGEADJPREV                   DISTYPE
# 1         NaN  EDUCATE03      AGEADJPREV                   DISTYPE
# 2         NaN  EDUCATE02      AGEADJPREV                   DISTYPE
# 3         NaN   INCOME03      AGEADJPREV                   DISTYPE
# 4         NaN   INCOME03      AGEADJPREV                   DISTYPE
#
#   StratificationID1 StratificationCategoryID2 StratificationID2
# 0           SELFDIS                       NaN               NaN
# 1            INDDIS                       NaN               NaN
# 2            INDDIS                       NaN               NaN
# 3            COGDIS                       NaN               NaN
# 4            INDDIS                       NaN               NaN
#
# [5 rows x 24 columns]

# %%
# Check for missing values in the DataFrame
missing_values = df.isnull().sum()

# Print the missing values counts
print("Missing values in the DataFrame:")
print(missing_values)
# Out:
# Missing values in the DataFrame:
# Rowid                         118529
# Year                               0
# LocationAbbr                       0
# LocationDesc                       0
# DataSource                         0
# Category                           0
# Indicator                          0
# Response                        9216
# Data_Value_Unit                    0
# Data_Value_Type                    0
# Data_Value                     65778
# Data_Value_Alt                 65778
# Data_Value_Footnote_Symbol    578578
# Data_Value_Footnote           578578
# Low_Confidence_Limit           65778
# High_Confidence_Limit          65778
# Number                         65778
# WeightedNumber                 65778
# StratificationCategory1            0
# Stratification1                    0
# StratificationCategory2       234636
# Stratification2               234636
# CategoryID                         0
# IndicatorID                        0
# Geolocation                   567156
# LocationID                         0
# ResponseID                         0
# DataValueTypeID                    0
# StratificationCategoryID1          0
# StratificationID1                  0
# StratificationCategoryID2     234636
# StratificationID2             234636
# dtype: int64

# %%
# Drop the specified columns
df = df.drop(columns=['Rowid', 'Data_Value_Footnote_Symbol', 'Data_Value_Footnote', 'StratificationCategory2',	'Stratification2', 
                              'Data_Value_Alt','DataSource', 'Geolocation','LocationID','ResponseID','DataValueTypeID','StratificationCategoryID1',
                              'StratificationID1','StratificationCategoryID2','StratificationID2'])

# Display the first few rows of the cleaned DataFrame
# df_cleaned.head()

# %%
# Using count() attribute
df_cleaned_count = df.count()
print(df_cleaned_count)
print(df.shape)
# Out:
# Year                       644356
# LocationAbbr               644356
# LocationDesc               644356
# Category                   644356
# Indicator                  644356
# Response                   635140
# Data_Value_Unit            644356
# Data_Value_Type            644356
# Data_Value                 578578
# Low_Confidence_Limit       578578
# High_Confidence_Limit      578578
# Number                     578578
# WeightedNumber             578578
# StratificationCategory1    644356
# Stratification1            644356
# CategoryID                 644356
# IndicatorID                644356
# dtype: int64
# (644356, 17)

# %%
# Display summary statistics
df.describe(include = 'all').T
# Out:
#                             count unique  \
# Year                     644356.0    NaN
# LocationAbbr               644356     65
# LocationDesc               644356     65
# Category                   644356      8
# Indicator                  644356     42
# Response                   635140     62
# Data_Value_Unit            644356      1
# Data_Value_Type            644356      2
# Data_Value               578578.0    NaN
# Low_Confidence_Limit     578578.0    NaN
# High_Confidence_Limit    578578.0    NaN
# Number                   578578.0    NaN
# WeightedNumber           578578.0    NaN
# StratificationCategory1    644356      3
# Stratification1            644356      9
# CategoryID                 644356      8
# IndicatorID                644356     42
#
#                                                                        top  \
# Year                                                                   NaN
# LocationAbbr                                                            DC
# LocationDesc                                          District of Columbia
# Category                                          Health Risks & Behaviors
# Indicator                Body mass index category among adults 18 years...
# Response                                                                No
# Data_Value_Unit                                                          %
# Data_Value_Type                                    Age-adjusted Prevalence
# Data_Value                                                             NaN
# Low_Confidence_Limit                                                   NaN
# High_Confidence_Limit                                                  NaN
# Number                                                                 NaN
# WeightedNumber                                                         NaN
# StratificationCategory1                                  Disability Status
# Stratification1                                             Any Disability
# CategoryID                                                          HLTHRB
# IndicatorID                                                            BMI
#
#                            freq           mean             std     min  \
# Year                        NaN    2018.437783         1.69878  2016.0
# LocationAbbr              10068            NaN             NaN     NaN
# LocationDesc              10068            NaN             NaN     NaN
# Category                 147336            NaN             NaN     NaN
# Indicator                 36864            NaN             NaN     NaN
# Response                 183218            NaN             NaN     NaN
# Data_Value_Unit          644356            NaN             NaN     NaN
# Data_Value_Type          483384            NaN             NaN     NaN
# Data_Value                  NaN       42.25289       28.947211     0.1
# Low_Confidence_Limit        NaN      37.898096       28.456481     0.0
# High_Confidence_Limit       NaN      46.728883       29.148859     0.1
# Number                      NaN    1518.155129     7131.018111     1.0
# WeightedNumber              NaN  856674.406697  4137684.208675    43.0
# StratificationCategory1  479228            NaN             NaN     NaN
# Stratification1          239614            NaN             NaN     NaN
# CategoryID               147336            NaN             NaN     NaN
# IndicatorID               36864            NaN             NaN     NaN
#
#                              25%       50%        75%          max
# Year                      2017.0    2018.0     2020.0       2021.0
# LocationAbbr                 NaN       NaN        NaN          NaN
# LocationDesc                 NaN       NaN        NaN          NaN
# Category                     NaN       NaN        NaN          NaN
# Indicator                    NaN       NaN        NaN          NaN
# Response                     NaN       NaN        NaN          NaN
# Data_Value_Unit              NaN       NaN        NaN          NaN
# Data_Value_Type              NaN       NaN        NaN          NaN
# Data_Value                  17.5      35.9       66.2        100.0
# Low_Confidence_Limit        13.6      30.0       60.3         99.9
# High_Confidence_Limit       21.8      42.3       71.8        100.0
# Number                     122.0     344.0     1004.0     327817.0
# WeightedNumber           43178.0  147578.5  495804.25  181223676.0
# StratificationCategory1      NaN       NaN        NaN          NaN
# Stratification1              NaN       NaN        NaN          NaN
# CategoryID                   NaN       NaN        NaN          NaN
# IndicatorID                  NaN       NaN        NaN          NaN

# %%
# Analysis of Data Value column based on Indicator.
# Assuming the data is missing and doesn't left blank intentionally.
indicators = df.groupby('Indicator')['Data_Value'].apply(lambda x: x.isnull().sum())
indicators
# Out:
# Indicator
# Aerobic physical activity level among adults 18 years of age or older                                                       539
# Attempted to quit smoking in the past 12 months among adults 18 years of age or older who are current every day smokers    3610
# Average hours of sleep in a 24-hour period among adults 18 years of age or older                                           1721
# Binge drinking in the past 30 days among adults 18 years of age or older                                                   1388
# Body mass index category among adults 18 years of age or older                                                             6760
# Could not see a doctor due to cost in the past 12 months among adults 18 years of age or older                             1196
# Current asthma among adults 18 years of age or older                                                                       1442
# Current e-cigarette use among adults 18 years of age or older                                                              1659
# Disability status and types among adults 18 years of age or older                                                             3
# Disability status and types among adults 18 years of age or older by age group                                              119
# Disability status and types among adults 18 years of age or older by race/ethnicity                                        9303
# Disability status and types among adults 18 years of age or older by sex                                                     20
# Disability status and types among adults 18 years of age or older by veteran status                                         256
# Education level among adults 18 years of age or older                                                                       293
# Employment status among adults 18 years of age or older                                                                    1021
# Ever been tested for HIV among adults 18 to 64 years of age                                                                1225
# Ever had a stroke among adults 18 years of age or older                                                                    3171
# Ever had arthritis among adults 18 years of age or older                                                                    834
# Ever had cancer (excluding skin cancer) among adults 18 years of age or older                                              2215
# Ever had chronic obstructive pulmonary disease (COPD) among adults 18 years of age or older                                2063
# Ever had depression among adults 18 years of age or older                                                                  1011
# Ever had diabetes among adults 18 years of age or older                                                                    1197
# Ever had heart disease among adults 18 years of age or older                                                               2245
# Ever had high blood pressure among adults 18 years of age or older                                                          362
# Ever had high cholesterol among adults 20 years of age or older                                                             420
# Fair or poor self-rated health among adults 18 years of age or older                                                        990
# Fallen in the past 12 months among adults 45 years of age or older                                                          754
# Had a flu vaccine in the past 12 months among adults 18 years of age or older                                               762
# Health care coverage among adults 18 years of age or older                                                                 2084
# Income level among adults 18 years of age or older                                                                         1392
# Mammogram in the past 2 years among females 50 to 74 years of age                                                          1525
# Marital status among adults 18 years of age or older                                                                        305
# Meeting the physical activity guidelines among adults 18 years of age or older                                             1057
# Mentally unhealthy days in the past 30 days among adults 18 years of age or older                                          1732
# Personal doctor or health care provider among adults 18 years of age or older                                              2525
# Physically unhealthy days in the past 30 days among adults 18 years of age or older                                        1865
# Routine check-up in the past year among adults 18 years of age or older                                                     918
# Smoking status among adults 18 years of age or older                                                                       1500
# Taking medicine for high blood pressure among adults 18 years of age or older who have high blood pressure                 1083
# Up-to-date cervical cancer screening among females 21 to 65 years of age                                                   1922
# Up-to-date colorectal cancer screening among adults 50 to 75 years of age                                                   907
# Visited a dentist in the past year among adults 18 years of age or older                                                    384
# Name: Data_Value, dtype: int64

# %%
# Handling Missing values for Data Value, Low and High Confidence Limit, Number and Weighted Number based on Indicator column.

def fill_missing_with_indicator_mean(df):
    # Calculate the mean values for each indicator
    indicator_means = df.groupby('Indicator').agg({
        'Data_Value': 'mean',
        'Low_Confidence_Limit': 'mean',
        'High_Confidence_Limit': 'mean',
        'Number': 'mean',
        'WeightedNumber':'mean'
    }).reset_index()

    # Fill missing values in 'Data_Value' column
    df['Data_Value'].fillna(df['Indicator'].map(indicator_means.set_index('Indicator')['Data_Value']), inplace=True)

    # Fill missing values in 'Low_Confidence_Limit' column
    df['Low_Confidence_Limit'].fillna(df['Indicator'].map(indicator_means.set_index('Indicator')['Low_Confidence_Limit']), inplace=True)

    # Fill missing values in 'High_Confidence_Limit' column
    df['High_Confidence_Limit'].fillna(df['Indicator'].map(indicator_means.set_index('Indicator')['High_Confidence_Limit']), inplace=True)

    df['Number'].fillna(df['Indicator'].map(indicator_means.set_index('Indicator')['Number']), inplace=True)

    df['WeightedNumber'].fillna(df['Indicator'].map(indicator_means.set_index('Indicator')['WeightedNumber']), inplace=True)

    return df

# %%
df = fill_missing_with_indicator_mean(df)
df.count()
# Out:
# Year                       644356
# LocationAbbr               644356
# LocationDesc               644356
# Category                   644356
# Indicator                  644356
# Response                   635140
# Data_Value_Unit            644356
# Data_Value_Type            644356
# Data_Value                 644356
# Low_Confidence_Limit       644356
# High_Confidence_Limit      644356
# Number                     644356
# WeightedNumber             644356
# StratificationCategory1    644356
# Stratification1            644356
# CategoryID                 644356
# IndicatorID                644356
# dtype: int64

# %%
# Create a new Feature named Income_Level_Category based on Income level values.
df['Indicator'].unique()
# Out:
# array(['Employment status among adults 18 years of age or older',
#        'Education level among adults 18 years of age or older',
#        'Income level among adults 18 years of age or older',
#        'Disability status and types among adults 18 years of age or older by veteran status',
#        'Marital status among adults 18 years of age or older',
#        'Body mass index category among adults 18 years of age or older',
#        'Smoking status among adults 18 years of age or older',
#        'Binge drinking in the past 30 days among adults 18 years of age or older',
#        'Disability status and types among adults 18 years of age or older',
#        'Disability status and types among adults 18 years of age or older by age group',
#        'Current asthma among adults 18 years of age or older',
#        'Ever had diabetes among adults 18 years of age or older',
#        'Ever had a stroke among adults 18 years of age or older',
#        'Up-to-date cervical cancer screening among females 21 to 65 years of age',
#        'Up-to-date colorectal cancer screening among adults 50 to 75 years of age',
#        'Ever had depression among adults 18 years of age or older',
#        'Personal doctor or health care provider among adults 18 years of age or older',
#        'Mentally unhealthy days in the past 30 days among adults 18 years of age or older',
#        'Current e-cigarette use among adults 18 years of age or older',
#        'Physically unhealthy days in the past 30 days among adults 18 years of age or older',
#        'Ever had arthritis among adults 18 years of age or older',
#        'Visited a dentist in the past year among adults 18 years of age or older',
#        'Routine check-up in the past year among adults 18 years of age or older',
#        'Health care coverage among adults 18 years of age or older',
#        'Average hours of sleep in a 24-hour period among adults 18 years of age or older',
#        'Had a flu vaccine in the past 12 months among adults 18 years of age or older',
#        'Ever had chronic obstructive pulmonary disease (COPD) among adults 18 years of age or older',
#        'Mammogram in the past 2 years among females 50 to 74 years of age',
#        'Fallen in the past 12 months among adults 45 years of age or older',
#        'Fair or poor self-rated health among adults 18 years of age or older',
#        'Ever had cancer (excluding skin cancer) among adults 18 years of age or older',
#        'Attempted to quit smoking in the past 12 months among adults 18 years of age or older who are current every day smokers',
#        'Ever had heart disease among adults 18 years of age or older',
#        'Ever been tested for HIV among adults 18 to 64 years of age',
#        'Disability status and types among adults 18 years of age or older by sex',
#        'Disability status and types among adults 18 years of age or older by race/ethnicity',
#        'Could not see a doctor due to cost in the past 12 months among adults 18 years of age or older',
#        'Ever had high cholesterol among adults 20 years of age or older',
#        'Ever had high blood pressure among adults 18 years of age or older',
#        'Meeting the physical activity guidelines among adults 18 years of age or older',
#        'Aerobic physical activity level among adults 18 years of age or older',
#        'Taking medicine for high blood pressure among adults 18 years of age or older who have high blood pressure'],
#       dtype=object)

# %%
df['Stratification1'].unique()
# Out:
# array(['Self-care Disability', 'Independent Living Disability',
#        'Cognitive Disability', 'Hearing Disability', 'Any Disability',
#        'No Disability', 'Mobility Disability', 'Vision Disability',
#        'Overall'], dtype=object)

# %%
df['Response'].unique()
# Out:
# array(['Employed', 'College Graduate', 'High School Graduate',
#        '$25,000 to <$35,000', 'Veteran', 'Widowed', 'Other',
#        'Underweight', '$15,000 to <$25,000', 'Normal Weight',
#        'Never Smoker', 'No', '<$15,000', 'Never Married', '$50,000+',
#        'Overweight', 'Obese', 'Divorced / Separated', 'Yes',
#        'Married / Unmarried Couple', 'Hearing Disability',
#        '$35,000 to <$50,000', '45-64', 'Out of Work', 'Non-Veteran',
#        'Some High School or Less', '18-44', '65+', 'Current Smoker',
#        'Unable to Work', 'Vision Disability', nan, '0 Days', '14+ Days',
#        '1-6 Hours', '1-13 Days', '2+ Providers',
#        'Independent Living Disability', '10+ Hours', '1 Provider',
#        '7-9 Hours', 'Female', 'Former Smoker',
#        'Other / Multirace, non-Hispanic', 'White, non-Hispanic',
#        'Asian, non-Hispanic', 'No Disability',
#        'Native Hawaiian or Other Pacific Islander, non-Hispanic',
#        'American Indian or Alaska Native, non-Hispanic', 'Hispanic',
#        'Black, non-Hispanic', 'Self-care Disability', 'Male',
#        'Mobility Disability', 'Any Disability', 'Cognitive Disability',
#        'Meets Muscle Strengthening Only', 'Meets Neither',
#        'Meets Aerobic Only', 'Inactive', 'Insufficiently Active',
#        'Sufficiently Active',
#        'Meets Both Aerobic and Muscle Strengthening'], dtype=object)

# %% [raw]
# # Create a new Feature based on Age.
# df['Stratification1'] = df['Stratification1'].astype(str)
# df['Response'] = df['Response'].astype(str)
# df['Age_Group'] = pd.concat([df['Stratification1'], df['Response']], axis=1).apply('-'.join, axis=1)
# indicators = df['Indicator'].unique()
# age_groups = df['Age_Group'].unique()
# for indicator in indicators:
#     for age_group in age_groups:
#         # Create a binary feature indicating whether the indicator is relevant to the age group
#         df[f'{indicator}_for_{age_group}_Binary'] = (df['Indicator'] == indicator) & (df['Age_Group'] == age_group)

# %% [raw]
# # Extract unique values of indicators related to Employment Status and responses
# employment_indicators = df[df['Indicator'].str.contains('Employment', case=False)]['Indicator'].unique()
# responses = df['Response'].unique()
#
# # Create binary features for each employment status and response combination
# for indicator in employment_indicators:
#     for response in responses:
#         # Create a binary feature indicating whether the record corresponds to a specific employment status
#         df[f'{indicator.replace(" ", "_").lower()}_for_{response.replace(" ", "_").lower()}_Binary'] = (
#             (df['Indicator'] == indicator) & (df['Response'] == response)
#         ).astype(int)
#
# # Display the updated DataFrame with the new features
# #print(df.head())

# %% [raw]
# # Extract unique values of indicators related to Smoking Status and responses
# smoking_indicators = df[df['Indicator'].str.contains('Smoking status', case=False)]['Indicator'].unique()
# responses = df['Response'].unique()
#
# # Create binary features for each smoking status and response combination
# for indicator in smoking_indicators:
#     for response in responses:
#         # Create a binary feature indicating whether the record corresponds to a specific smoking status
#         df[f'{indicator.replace(" ", "_").lower()}_for_{response.replace(" ", "_").lower()}_Binary'] = (
#             (df['Indicator'] == indicator) & (df['Response'] == response)
#         ).astype(int)

# %% [raw]
# # Extract unique values of indicators related to Chronic Disease and responses
# chronic_disease_indicators = df[df['Indicator'].str.contains('chronic', case=False)]['Indicator'].unique()
# responses = df['Response'].unique()
#
# # Create binary features for each chronic disease and response combination
# for indicator in chronic_disease_indicators:
#     for response in responses:
#         # Create a binary feature indicating whether the record corresponds to a specific chronic disease
#         df[f'{indicator.replace(" ", "_").lower()}_for_{response.replace(" ", "_").lower()}_Binary'] = (
#             (df['Indicator'] == indicator) & (df['Response'] == response)
#         ).astype(int)

# %%
# Filter the DataFrame to include only relevant indicators
relevant_indicators = ['Employment status among adults 18 years of age or older',
                      'Income level among adults 18 years of age or older']
filtered_df = df[df['Indicator'].isin(relevant_indicators)]

# Group by 'Stratification' and 'Indicator', and aggregate 'Response' values
grouped_df = filtered_df.groupby(['Stratification1', 'Indicator'])['Response'].first().unstack()

# Create a new column representing socioeconomic status by combining 'Employment status' and 'Income level'
grouped_df['Socioeconomic Status'] = grouped_df['Employment status among adults 18 years of age or older'] + ' & ' + grouped_df['Income level among adults 18 years of age or older']

# Reset index to convert 'Stratification' back to a regular column
grouped_df.reset_index(inplace=True)

# Merge the new socioeconomic status column back into the original DataFrame
df = pd.merge(df, grouped_df[['Stratification1', 'Socioeconomic Status']], on='Stratification1', how='left')

# %%
# Create a feature named chronic disease describing whether person had a chrnic disease or not.
chronic_diseases = ['Current asthma among adults 18 years of age or older',
                    'Ever had diabetes among adults 18 years of age or older',
                    'Ever had a stroke among adults 18 years of age or older',
                    'Ever had cancer (excluding skin cancer) among adults 18 years of age or older',
                    'Ever had heart disease among adults 18 years of age or older',
                    'Ever had chronic obstructive pulmonary disease (COPD) among adults 18 years of age or older']
df['chronic_disease'] = df['Indicator'].isin(chronic_diseases).astype(int)

# %%
def extract_income_category(x):
    if isinstance(x, str) and '$' in x:
        return x
    else:
        return None

df['Income_Category'] = df['Response'].apply(extract_income_category)

# Create a new column 'Education_Level' by extracting education levels from 'Response'
def extract_education_level(x):
    if isinstance(x, str) and ('School' in x or 'College' in x):
        return x
    else:
        return None

df['Education_Level'] = df['Response'].apply(extract_education_level)

# %%
# Define a function to generate the new feature
def generate_disability_feature(row):
    if row['Indicator'].startswith('Disability status') and row['Stratification1'] != 'Overall':
        return f"{row['Indicator']} - {row['Stratification1']}"
    else:
        return None  # If the row doesn't meet the criteria, return None or any other appropriate value

# Apply the function to create the new column
df['Disability_Status_Feature'] = df.apply(generate_disability_feature, axis=1)

# %%
# Count of Responses by Indicator and Stratification
df['Response_Count'] = df.groupby(['Indicator', 'Stratification1'])['Response'].transform('count')

# Percentage of Responses by Indicator and Stratification
df['Response_Percentage'] = df.groupby(['Indicator', 'Stratification1'])['Response'].transform(lambda x: x.count() / len(x))

# Summary statistics of Responses by Indicator and Stratification
summary_stats = df.groupby(['Indicator', 'Stratification1'])['Response'].describe()
summary_stats = summary_stats.reset_index().rename(columns={'50%': 'Median', 'std': 'Standard_Deviation'})

# Indicator-Stratification Interaction Terms
df['Indicator_Stratification_Interact'] = df['Indicator'] + '_' + df['Stratification1']

# Binary Encoding for Response Categories
binary_encoded = pd.get_dummies(df, columns=['Response'], prefix='Response')

# Concatenate the original DataFrame with the binary-encoded columns
df = pd.concat([df, binary_encoded.iloc[:, -len(df['Response'].unique()):]], axis=1)

# %%
df.head()
# Out:
#    Year LocationAbbr          LocationDesc      Category  \
# 0  2019           DC  District of Columbia  Demographics
# 1  2020           NJ            New Jersey  Demographics
# 2  2020           WV         West Virginia  Demographics
# 3  2020           RI          Rhode Island  Demographics
# 4  2020         HHS8          HHS Region 8  Demographics
#
#                                            Indicator              Response  \
# 0  Employment status among adults 18 years of age...              Employed
# 1  Education level among adults 18 years of age o...      College Graduate
# 2  Education level among adults 18 years of age o...  High School Graduate
# 3  Income level among adults 18 years of age or o...   $25,000 to <$35,000
# 4  Income level among adults 18 years of age or o...   $25,000 to <$35,000
#
#   Data_Value_Unit          Data_Value_Type  Data_Value  Low_Confidence_Limit  \
# 0               %  Age-adjusted Prevalence   26.303808             21.790104
# 1               %  Age-adjusted Prevalence   15.000000             11.700000
# 2               %  Age-adjusted Prevalence   69.000000             63.300000
# 3               %  Age-adjusted Prevalence   10.700000              7.200000
# 4               %  Age-adjusted Prevalence   13.500000             11.100000
#
#    ...  Response_Self-care Disability  Response_Some High School or Less  \
# 0  ...                          False                              False
# 1  ...                          False                              False
# 2  ...                          False                              False
# 3  ...                          False                              False
# 4  ...                          False                              False
#
#    Response_Sufficiently Active Response_Unable to Work Response_Underweight  \
# 0                         False                   False                False
# 1                         False                   False                False
# 2                         False                   False                False
# 3                         False                   False                False
# 4                         False                   False                False
#
#   Response_Veteran Response_Vision Disability Response_White, non-Hispanic  \
# 0            False                      False                        False
# 1            False                      False                        False
# 2            False                      False                        False
# 3            False                      False                        False
# 4            False                      False                        False
#
#    Response_Widowed Response_Yes
# 0             False        False
# 1             False        False
# 2             False        False
# 3             False        False
# 4             False        False
#
# [5 rows x 88 columns]

# %%
df.columns
# Out:
# Index(['Year', 'LocationAbbr', 'LocationDesc', 'Category', 'Indicator',
#        'Response', 'Data_Value_Unit', 'Data_Value_Type', 'Data_Value',
#        'Low_Confidence_Limit', 'High_Confidence_Limit', 'Number',
#        'WeightedNumber', 'StratificationCategory1', 'Stratification1',
#        'CategoryID', 'IndicatorID', 'Socioeconomic Status', 'chronic_disease',
#        'Income_Category', 'Education_Level', 'Disability_Status_Feature',
#        'Response_Count', 'Response_Percentage',
#        'Indicator_Stratification_Interact',
#        'Indicator_Stratification_Interact', 'Response_$15,000 to <$25,000',
#        'Response_$25,000 to <$35,000', 'Response_$35,000 to <$50,000',
#        'Response_$50,000+', 'Response_0 Days', 'Response_1 Provider',
#        'Response_1-13 Days', 'Response_1-6 Hours', 'Response_10+ Hours',
#        'Response_14+ Days', 'Response_18-44', 'Response_2+ Providers',
#        'Response_45-64', 'Response_65+', 'Response_7-9 Hours',
#        'Response_<$15,000',
#        'Response_American Indian or Alaska Native, non-Hispanic',
#        'Response_Any Disability', 'Response_Asian, non-Hispanic',
#        'Response_Black, non-Hispanic', 'Response_Cognitive Disability',
#        'Response_College Graduate', 'Response_Current Smoker',
#        'Response_Divorced / Separated', 'Response_Employed', 'Response_Female',
#        'Response_Former Smoker', 'Response_Hearing Disability',
#        'Response_High School Graduate', 'Response_Hispanic',
#        'Response_Inactive', 'Response_Independent Living Disability',
#        'Response_Insufficiently Active', 'Response_Male',
#        'Response_Married / Unmarried Couple', 'Response_Meets Aerobic Only',
#        'Response_Meets Both Aerobic and Muscle Strengthening',
#        'Response_Meets Muscle Strengthening Only', 'Response_Meets Neither',
#        'Response_Mobility Disability',
#        'Response_Native Hawaiian or Other Pacific Islander, non-Hispanic',
#        'Response_Never Married', 'Response_Never Smoker', 'Response_No',
#        'Response_No Disability', 'Response_Non-Veteran',
#        'Response_Normal Weight', 'Response_Obese', 'Response_Other',
#        'Response_Other / Multirace, non-Hispanic', 'Response_Out of Work',
#        'Response_Overweight', 'Response_Self-care Disability',
#        'Response_Some High School or Less', 'Response_Sufficiently Active',
#        'Response_Unable to Work', 'Response_Underweight', 'Response_Veteran',
#        'Response_Vision Disability', 'Response_White, non-Hispanic',
#        'Response_Widowed', 'Response_Yes'],
#       dtype='object')

# %% [raw]
# Exploratory Data Analysis

# %%
#Histogram of Data_Value
plt.figure(figsize=(8, 6))
sns.histplot(df['Data_Value'], bins=20, kde=True)
plt.title('Distribution of Data Values')
plt.xlabel('Data Value')
plt.ylabel('Frequency')
plt.show()

# %%
# Bar plot of Response_Count by LocationDesc
plt.figure(figsize=(12, 8))
sns.barplot(x ='Response_Count', y='LocationDesc', data=df.sort_values(by='Response_Count', ascending=False).head(10))
plt.title('Top 10 Locations by Response Count')
plt.xlabel('Response Count')
plt.ylabel('Location')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Stratification1', data=df, palette='viridis')
plt.title('Count of Stratification1 Categories')
plt.xlabel('Stratification1')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.violinplot(x='Stratification1', y='Response_Percentage', data=df, palette='rocket')
plt.title('Response Percentage Distribution by Stratification1')
plt.xlabel('Stratification1')
plt.ylabel('Response Percentage')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(x='Stratification1', hue='Category', data=df, palette='Set2')
plt.title('Distribution of Categories by Stratification1')
plt.xlabel('Stratification1')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Category', loc='upper right')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8, 8))
df['Stratification1'].value_counts().plot.pie(autopct='%1.1f%%', startangle=45, colors=sns.color_palette('Pastel1', len(df['Stratification1'].unique())))
plt.title('Proportion of Stratification1 Categories')
plt.ylabel('')
plt.tight_layout()
plt.show()
